# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
import mplcyberpunk
from scipy.stats import skew
from sklearn.model_selection import KFold, cross_val_score
plt.style.use("cyberpunk")
pd.options.display.max_columns
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Documentation Reading
# After reading the details of at the webpage, I found that, the column names are
#
#     - WECs position {X1, X2, â€¦, X16; Y1, Y2,â€¦, Y16} continuous from 0 to 566 (m).
#     - WECs absorbed power: {P1, P2, â€¦, P16}
#     - Total power output of the farm: Powerall
#
# Thus, giving names to each and every column

# %%
column_names = ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'Y1', 'Y2', 'Y3', 'Y4', 'Y5', 'Y6', 'Y7', 'Y8', 'Y9', 'Y10', 'Y11', 'Y12', 'Y13', 'Y14', 'Y15', 'Y16', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15', 'P16', 'PowerAll']

# %%
adelaide = pd.read_csv("Adelaide_Data_1.csv", names=column_names)

# %% [markdown]
# ## Adelaide

# %%
adelaide.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  316.5855  223.9277  182.3434  551.5497    7.8641  243.1339  361.0877
# 1  530.3136   68.7031   31.5983  175.2582  516.1441   63.4652   67.0954
# 2   27.3967  399.0488  565.6854  394.0466  120.2245  558.1293  546.4520
# 3  346.1526   59.6375  226.2742  280.9095  402.2161  218.7181  207.0407
# 4  317.9144  551.8542  335.4745   40.0240  316.6285  365.6434  416.3060
#
#          X8        X9       X10  ...          P8          P9         P10  \
# 0  115.9284   78.6087  468.3799  ...  82322.0277  98069.1011  86578.6330
# 1  369.4486   14.0930  375.4462  ...  83920.1033  80968.0044  87108.1328
# 2   27.3256  314.1051  235.9476  ...  97358.7395  93437.7170  69940.2554
# 3  339.5676    0.0000    0.0000  ...  80399.3841  89349.6141  85048.3860
# 4  562.1028  211.3577  143.1255  ...  97088.1761  81187.3982  63591.6729
#
#           P11         P12         P13         P14         P15         P16  \
# 0  93016.4133  63145.1829  98353.1952  80225.1390  98447.2846  97570.2225
# 1  68065.1856  99061.3812  77549.1426  99013.1628  78234.4337  84633.6493
# 2  92864.1192  60887.8095  72306.6556  81151.1515  83030.9726  94779.6131
# 3  70038.2271  92797.3569  97653.8121  74903.3740  71690.6549  96220.4768
# 4  92418.1977  82454.8256  97091.7749  85937.5437  66823.1572  93683.0996
#
#       PowerAll
# 0  1370374.145
# 1  1340929.765
# 2  1352031.511
# 3  1396754.375
# 4  1355708.577
#
# [5 rows x 49 columns]

# %%
adelaide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71999 entries, 0 to 71998
# Data columns (total 49 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   X1        71999 non-null  float64
#  1   X2        71999 non-null  float64
#  2   X3        71999 non-null  float64
#  3   X4        71999 non-null  float64
#  4   X5        71999 non-null  float64
#  5   X6        71999 non-null  float64
#  6   X7        71999 non-null  float64
#  7   X8        71999 non-null  float64
#  8   X9        71999 non-null  float64
#  9   X10       71999 non-null  float64
#  10  X11       71999 non-null  float64
#  11  X12       71999 non-null  float64
#  12  X13       71999 non-null  float64
#  13  X14       71999 non-null  float64
#  14  X15       71999 non-null  float64
#  15  X16       71999 non-null  float64
#  16  Y1        71999 non-null  float64
#  17  Y2        71999 non-null  float64
#  18  Y3        71999 non-null  float64
#  19  Y4        71999 non-null  float64
#  20  Y5        71999 non-null  float64
#  21  Y6        71999 non-null  float64
#  22  Y7        71999 non-null  float64
#  23  Y8        71999 non-null  float64
#  24  Y9        71999 non-null  float64
#  25  Y10       71999 non-null  float64
#  26  Y11       71999 non-null  float64
#  27  Y12       71999 non-null  float64
#  28  Y13       71999 non-null  float64
#  29  Y14       71999 non-null  float64
#  30  Y15       71999 non-null  float64
#  31  Y16       71999 non-null  float64
#  32  P1        71999 non-null  float64
#  33  P2        71999 non-null  float64
#  34  P3        71999 non-null  float64
#  35  P4        71999 non-null  float64
#  36  P5        71999 non-null  float64
#  37  P6        71999 non-null  float64
#  38  P7        71999 non-null  float64
#  39  P8        71999 non-null  float64
#  40  P9        71999 non-null  float64
#  41  P10       71999 non-null  float64
#  42  P11       71999 non-null  float64
#  43  P12       71999 non-null  float64
#  44  P13       71999 non-null  float64
#  45  P14       71999 non-null  float64
#  46  P15       71999 non-null  float64
#  47  P16       71999 non-null  float64
#  48  PowerAll  71999 non-null  float64
# dtypes: float64(49)
# memory usage: 26.9 MB

# %%
def missing_data(df):
    total = df.isnull().sum().sort_values(ascending = False)
    Percentage = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
    return pd.concat([total, Percentage], axis = 1, keys = ['Total', 'Percentage'])

missing_data(adelaide)
# Out:
#           Total  Percentage
# X1            0         0.0
# Y10           0         0.0
# Y12           0         0.0
# Y13           0         0.0
# Y14           0         0.0
# Y15           0         0.0
# Y16           0         0.0
# P1            0         0.0
# P2            0         0.0
# P3            0         0.0
# P4            0         0.0
# P5            0         0.0
# P6            0         0.0
# P7            0         0.0
# P8            0         0.0
# P9            0         0.0
# P10           0         0.0
# P11           0         0.0
# P12           0         0.0
# P13           0         0.0
# P14           0         0.0
# P15           0         0.0
# P16           0         0.0
# Y11           0         0.0
# Y9            0         0.0
# X2            0         0.0
# Y8            0         0.0
# X3            0         0.0
# X4            0         0.0
# X5            0         0.0
# X6            0         0.0
# X7            0         0.0
# X8            0         0.0
# X9            0         0.0
# X10           0         0.0
# X11           0         0.0
# X12           0         0.0
# X13           0         0.0
# X14           0         0.0
# X15           0         0.0
# X16           0         0.0
# Y1            0         0.0
# Y2            0         0.0
# Y3            0         0.0
# Y4            0         0.0
# Y5            0         0.0
# Y6            0         0.0
# Y7            0         0.0
# PowerAll      0         0.0

# %%
def plot_zeros_per_column(df):
    zero_counts = (df == 0).sum()
    zero_counts.plot(kind='bar', figsize=(10, 6))
    plt.title('Number of Zeros in Each Column')
    plt.xlabel('Columns')
    plt.ylabel('Number of Zeros')
    plt.xticks(rotation=45)
    plt.grid(axis='y')
    plt.show()

plot_zeros_per_column(adelaide)

# %%
def count_rows_with_all_zeros(df):
    all_zeros_mask = (df == 0).all(axis=1)
    num_rows_with_all_zeros = all_zeros_mask.sum()
    return num_rows_with_all_zeros

count_rows_with_all_zeros(adelaide)
# Out:
# 0

# %% [markdown]
# ## Inference
#     - No null values in any column of the datasets
#     - If zeros are considered as null, then we have a lot of zeros in every column, moreover there is no documentation to say zero should be considered null
#     - No rows with all zeros in any column
#     - No negative values in any column

# %%
def transform_col(df):
    skewed_cols = df.skew().abs() > 0.5
    for col in skewed_cols.index[skewed_cols]:
        df[col] = np.log1p(df[col])
    return df

# %%
adelaide = transform_col(adelaide)

# %%
def plot_hist_for_all_columns(df):
    num_cols = df.shape[1]
    num_rows = math.ceil(num_cols / 3)

    fig, axes = plt.subplots(num_rows, 3, figsize=(15, num_rows * 5))
    axes = axes.flatten()

    for i, col in enumerate(df.columns):
        ax = axes[i]
        sns.histplot(df[col], ax=ax, kde=True)
        ax.set_title(col)
        ax.set_xlabel('')
        ax.set_ylabel('')


    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
plot_hist_for_all_columns(adelaide)

# %% [markdown]
# ## Scaling

# %%
scaler1 = StandardScaler()
scaler1.fit(adelaide)
# Out:
# StandardScaler()

# %% [markdown]
# ## Splitting Data

# %%
target1 = adelaide['PowerAll']
adelaide.drop(columns=['PowerAll'], inplace = True)

# %% [markdown]
# ## Modelling

# %%
_ = setup(data=pd.concat([adelaide, target1], axis=1), target = 'PowerAll')
# Out:
# <style type="text/css">
# #T_06aca_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_06aca" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06aca_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_06aca_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06aca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06aca_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_06aca_row0_col1" class="data row0 col1" >2231</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06aca_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_06aca_row1_col1" class="data row1 col1" >PowerAll</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06aca_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_06aca_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06aca_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_06aca_row3_col1" class="data row3 col1" >(71999, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06aca_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_06aca_row4_col1" class="data row4 col1" >(71999, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06aca_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_06aca_row5_col1" class="data row5 col1" >(50399, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06aca_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_06aca_row6_col1" class="data row6 col1" >(21600, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06aca_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_06aca_row7_col1" class="data row7 col1" >48</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_06aca_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_06aca_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_06aca_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_06aca_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_06aca_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_06aca_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_06aca_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_06aca_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_06aca_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_06aca_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_06aca_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_06aca_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_06aca_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_06aca_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_06aca_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_06aca_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_06aca_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_06aca_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_06aca_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_06aca_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_06aca_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_06aca_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_06aca_row18_col1" class="data row18 col1" >4dcd</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 19:09:31
# Status     . . . . . . . . . . . . . . . . . .         Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# <style type="text/css">
# #T_20d84 th {
#   text-align: left;
# }
# #T_20d84_row0_col0, #T_20d84_row0_col1, #T_20d84_row0_col2, #T_20d84_row0_col3, #T_20d84_row0_col4, #T_20d84_row0_col5, #T_20d84_row0_col6, #T_20d84_row0_col7, #T_20d84_row1_col0, #T_20d84_row1_col1, #T_20d84_row1_col2, #T_20d84_row1_col3, #T_20d84_row1_col4, #T_20d84_row1_col5, #T_20d84_row1_col6, #T_20d84_row1_col7, #T_20d84_row2_col0, #T_20d84_row2_col1, #T_20d84_row2_col2, #T_20d84_row2_col3, #T_20d84_row2_col4, #T_20d84_row2_col5, #T_20d84_row2_col6, #T_20d84_row2_col7, #T_20d84_row3_col0, #T_20d84_row3_col1, #T_20d84_row3_col2, #T_20d84_row3_col3, #T_20d84_row3_col4, #T_20d84_row3_col5, #T_20d84_row3_col6, #T_20d84_row3_col7, #T_20d84_row4_col0, #T_20d84_row4_col1, #T_20d84_row4_col2, #T_20d84_row4_col3, #T_20d84_row4_col4, #T_20d84_row4_col5, #
>0.1230</td>
#     </tr>
#     <tr>
#       <th id="T_20d84_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_20d84_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_20d84_row3_col1" class="data row3 col1" >2152.9253</td>
#       <td id="T_20d84_row3_col2" class="data row3 col2" >7682356.3000</td>
#       <td id="T_20d84_row3_col3" class="data row3 col3" >2771.4766</td>
#       <td id="T_20d84_row3_col4" class="data row3 col4" >0.9976</td>
#       <td id="T_20d84_row3_col5" class="data row3 col5" >0.0020</td>
#       <td id="T_20d84_row3_col6" class="data row3 col6" >0.0015</td>
#       <td id="T_20d84_row3_col7" class="data row3 col7" >0.1810</td>
#     </tr>
#     <tr>
#       <th id="T_20d84_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_20d84_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_20d84_row4_col1" class="data row4 col1" >2312.2259</td>
#       <td id="T_20d84_row4_col2" class="data row4 col2" >8842814.4000</td>
#       <td id="T_20d84_row4_col3" class="data row4 col3" >2967.7176</td>
#       <td id="T_20d84_row4_col4" class="data row4 col4" >0.9972</td>
#       <td id="T_20d84_row4_col5" class="data row4 col5" >0.0021</td>
#       <td id="T_20d84_row4_col6" class="data row4 col6" >0.0016</td>
#       <td id="T_20d84_row4_col7" class="data row4 col7" >0.8810</td>
#     </tr>
#     <tr>
#       <th id="T_20d84_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_20d84_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_20d84_row5_col1" class="data row5 col1" >21400.6872</td>
#       <td id="T_20d84_row5_col2" class="data row5 col2" >894978263.5381</td>
#       <td id="T_20d84_row5_col3" class="data row5 col3" >29914.4090</td>
#       <td id="T_20d84_row5_col4" class="data row5 col4" >0.7170</td>
#       <td id="T_20d84_row5_col5" class="data row5 col5" >0.0217</td>
#       <td id="T_20d84_row5_col6" class="data row5 col6" >0.0154</td>
#       <td id="T_20d84_row5_col7" class="data row5 col7" >4.2430</td>
#     </tr>
#     <tr>
#       <th id="T_20d84_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_20d84_row6_col0" class="data row6 col0" >K Neighbors Regressor</td>
#       <td id="T_20d84_row6_col1" class="data row6 col1" >21977.0928</td>
#       <td id="T_20d84_row6_col2" class="data row6 col2" >932052915.2000</td>
#       <td id="T_20d84_row6_col3" class="data row6 col3" >30528.3283</td>
#       <td id="T_20d84_row6_col4" class="data row6 col4" >0.7052</td>
#       <td id="T_20d84_row6_col5" class="data row6 col5" >0.0220</td>
#       <td id="T_20d84_row6_col6" class="data row6 col6" >0.0158</td>
#       <td id="T_20d84_row6_col7" class="data row6 col7" >1.6350</td>
#     </tr>
#     <tr>
#       <th id="T_20d84_level0_row7" class="row_heading level0 row7" >en</th>
#       <td id="T_20d84_row7_col0" class="data row7 col0" >Elastic Net</td>
#       <td id="T_20d84_row7_col1" class="data row7 col1" >35799.5188</td>
#       <td id="T_20d84_row7_col2" class="data row7 col2" >1955687654.4000</td>
#       <td id="T_20d84_row7_col3" class="data row7 col3" >44222.1293</td>
#       <td id="T_20d84_row7_col4" class="data row7 col4" >0.3817</td>
#       <td id="T_20d84_row7_col5" class
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %% [markdown]
# ## Four Models performed nearly the same including
#
#     - Lasso Regression (Accuracy : 99.76%)
#     - Ridge Regression (Accuracy : 99.76%)
#     - Lasso Least Angle Regression (Accuracy : 99.76%)
#     - Bayesian Ridge (Accuracy : 99.76%)
#
# We have used 10-Fold Cross Validation
